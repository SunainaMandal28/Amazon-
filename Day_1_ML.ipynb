# %% [markdown]
# <a href="https://colab.research.google.com/github/SunainaMandal28/Amazon-/blob/main/Day_1_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
ones = np.ones(5)
ones
# Out:
# array([1., 1., 1., 1., 1.])

# %%
zeros = np.zeros(5)
zeros
# Out:
# array([0., 0., 0., 0., 0.])

# %%
ones = np.ones(5)
print(ones.dtype)
# Out:
# float64

# %%
ones = np.ones(5)
print(type(ones))
# Out:
# <class 'numpy.ndarray'>

# %%
arr1 = np.arange(8)
print(arr1)
# Out:
# [0 1 2 3 4 5 6 7]

# %%
arr1 = np.arange(3,8)
print(arr1)
# Out:
# [3 4 5 6 7]

# %%
arr1 = np.arange(2,10,2) #Even
print(arr1)
# Out:
# [2 4 6 8]

# %%
arr1 =np.arange(3)
arr2 =np.arange(3)
print(arr1,arr2)
# Out:
# [0 1 2] [0 1 2]

# %%
print (arr1 + arr2)
# Out:
# [0 2 4]

# %%
print (arr1 - arr2)
# Out:
# [0 0 0]

# %%
print (arr1 * arr2)
# Out:
# [0 1 4]

# %%
arr1 =np.arange(4)
arr2 =np.arange(4)
print (arr1/arr2)
# Out:
# [nan  1.  1.  1.]
# /tmp/ipython-input-1353368895.py:3: RuntimeWarning: invalid value encountered in divide
#   print (arr1/arr2)
